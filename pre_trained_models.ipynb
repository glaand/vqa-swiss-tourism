# %% [markdown]
# ## Pretrained VQA
# Vision-and-Language Transformer (ViLT), fine-tuned on VQAv2
#
# Pretrained Model: https://huggingface.co/dandelin/vilt-b32-finetuned-vqa

# %%
from transformers import ViltProcessor, ViltForQuestionAnswering
import requests
from PIL import Image
from io import BytesIO
import os
import pandas as pd

# %% [markdown]
# ## Code example

# %%
# Code Example

# prepare image + question
url = "http://images.cocodataset.org/val2017/000000039769.jpg"
image = Image.open(requests.get(url, stream=True).raw)
text = "How many cats are there?"

processor = ViltProcessor.from_pretrained("dandelin/vilt-b32-finetuned-vqa")
model = ViltForQuestionAnswering.from_pretrained("dandelin/vilt-b32-finetuned-vqa")

# prepare inputs
encoding = processor(image, text, return_tensors="pt")

# forward pass
outputs = model(**encoding)
logits = outputs.logits
probabilities = logits.softmax(dim=-1)

# get the predicted class and its confidence
predicted_class = logits.argmax(-1).item()
confidence = probabilities[0, predicted_class].item()

print("Predicted answer:", model.config.id2label[predicted_class])
print("Confidence:", confidence)
# Out:
# Predicted answer: 2
# Confidence: 0.9443891048431396

# %%
# Code Example

# prepare image + question
url = "http://images.cocodataset.org/val2017/000000039769.jpg"
image = Image.open(requests.get(url, stream=True).raw)
text = "Are there more than two cats?"

processor = ViltProcessor.from_pretrained("dandelin/vilt-b32-finetuned-vqa")
model = ViltForQuestionAnswering.from_pretrained("dandelin/vilt-b32-finetuned-vqa")

# prepare inputs
encoding = processor(image, text, return_tensors="pt")

# forward pass
outputs = model(**encoding)
logits = outputs.logits
probabilities = logits.softmax(dim=-1)

# get the predicted class and its confidence
predicted_class = logits.argmax(-1).item()
confidence = probabilities[0, predicted_class].item()

print("Predicted answer:", model.config.id2label[predicted_class])
print("Confidence:", confidence)
# Out:
# Predicted answer: no
# Confidence: 0.9986134767532349

# %%
# Code Example

# prepare image + question
url = "http://images.cocodataset.org/val2017/000000039769.jpg"
image = Image.open(requests.get(url, stream=True).raw)
text = "How many dogs are there?"

processor = ViltProcessor.from_pretrained("dandelin/vilt-b32-finetuned-vqa")
model = ViltForQuestionAnswering.from_pretrained("dandelin/vilt-b32-finetuned-vqa")

# prepare inputs
encoding = processor(image, text, return_tensors="pt")

# forward pass
outputs = model(**encoding)
logits = outputs.logits
probabilities = logits.softmax(dim=-1)

# get the predicted class and its confidence
predicted_class = logits.argmax(-1).item()
confidence = probabilities[0, predicted_class].item()

print("Predicted answer:", model.config.id2label[predicted_class])
print("Confidence:", confidence)
# Out:
# Predicted answer: 0
# Confidence: 0.9978933930397034

# %% [markdown]
# ![image.png](attachment:image.png)
# _____________
# ## Experiment

# %%
# slugging
def build_path(category:str, number_str:str, name:str):
    category = category.lower()
    name = name.lower().replace(" ", "_").replace("ä", "ae").replace("ö", "oe").replace("ü", "ue").replace("'", "_").replace("-", "_").replace(".", "")
    file_name = number_str + "_" + name + ".jpg"
    path = os.path.join("images", category, file_name)
    return path

# %%
# test
print(build_path("SWITZERLand", "19", "Jet d'EAU"))
print(build_path("SWITZERLand", "07", "KAPELLBRÜCKE"))
# Out:
# images\switzerland\19_jet_d_eau.jpg
# images\switzerland\07_kapellbruecke.jpg

# %%
def vilt_vqa(url_or_path:str, question:str, online:bool):
    if online:
        image = Image.open(requests.get(url_or_path, stream=True).raw)
    else:
        image = Image.open(url_or_path)
    processor = ViltProcessor.from_pretrained("dandelin/vilt-b32-finetuned-vqa")
    model = ViltForQuestionAnswering.from_pretrained("dandelin/vilt-b32-finetuned-vqa")

    # prepare inputs
    encoding = processor(image, question, return_tensors="pt")

    # forward pass
    outputs = model(**encoding)
    logits = outputs.logits
    probabilities = logits.softmax(dim=-1)

    # get the predicted answer and its confidence
    predicted_class = logits.argmax(-1).item()
    answer = model.config.id2label[predicted_class]
    confidence = probabilities[0, predicted_class].item()
    confidence = round(confidence, 4)
    # print("Predicted answer:", answer)
    # print("Confidence:", confidence)
    return answer, confidence

# %%
# test
test_path = build_path("SWITZERLand", "02", "BundesHAUS")
test_answer = vilt_vqa(test_path, "Is there text on the building?", False)
test_answer
# Out:
# ('yes', 0.4986)

# %%
switzerland_list = ["Matterhorn", "Bundeshaus", "Chateau de Chillon", "Creux du Van", "Bern Old City", 
                    "Jungfraujoch", "Kapellbrücke", "Ascona", "Grindelwald", "Chateau de Gruyeres", 
                    "Aletsch Glacier", "Lauterbrunnen", "Rheinfall", "Zermatt", "Lion Monument", 
                    "Schilthorn", "Lenzburg Castle", "Grossmünster","Jet d'Eau Lake Geneva", "Zytglogge"]

international_list = ["Eiffel Tower", "Uluru", "Louvre", "Lady Liberty", "Colosseum", "Niagara Falls", 
                      "Disney World", "Forbidden City", "Golden Gate Bridge", "Times Square", "Notre Dame",
                      "Sagrada Familia", "Neuschwanstein Castle", "Sydney Opera House", "Great Wall", 
                      "Florence Cathedral", "Mount Rushmore", "Brooklyn Bridge", "Grand Canyon", "Las Vegas Strip"]

grisons_list = ["Arosa", "Bergün", "Lai da Palpuogna", "samedan", "S-chanf", "Landwasser Viaduct", 
                "Brusio Spiral Viaduct", "Chur", "Lake Silvaplana", "St. Moritz", "Lake Cauma", 
                "White Turf", "Guarda", "Davos Schatzalp", "Ruinaulta", "Maienfeld", 
                "Muottas Muragl", "Oberengadin", "San Gian", "Corviglia Piz Nair"]

switzerland_paths = {}
for counter in range(len(switzerland_list)):
    if counter < 9:
        number_string = "0" + str(counter+1)
    else:
        number_string = str(counter+1)
    name = switzerland_list[counter]
    switzerland_paths[name] = build_path("switzerland", number_string, name)

international_paths = {}
for counter in range(len(international_list)):
    if counter < 9:
        number_string = "0" + str(counter+1)
    else:
        number_string = str(counter+1)
    name = international_list[counter]
    international_paths[name] = build_path("international", number_string, name)

grisons_paths = {}
for counter in range(len(grisons_list)):
    if counter < 9:
        number_string = "0" + str(counter+1)
    else:
        number_string = str(counter+1)
    name = grisons_list[counter]
    grisons_paths[name] = build_path("grisons", number_string, name)

# %%
# test
switzerland_paths
# Out:
# {'Matterhorn': 'images\\switzerland\\01_matterhorn.jpg',
#  'Bundeshaus': 'images\\switzerland\\02_bundeshaus.jpg',
#  'Chateau de Chillon': 'images\\switzerland\\03_chateau_de_chillon.jpg',
#  'Creux du Van': 'images\\switzerland\\04_creux_du_van.jpg',
#  'Bern Old City': 'images\\switzerland\\05_bern_old_city.jpg',
#  'Jungfraujoch': 'images\\switzerland\\06_jungfraujoch.jpg',
#  'Kapellbrücke': 'images\\switzerland\\07_kapellbruecke.jpg',
#  'Ascona': 'images\\switzerland\\08_ascona.jpg',
#  'Grindelwald': 'images\\switzerland\\09_grindelwald.jpg',
#  'Chateau de Gruyeres': 'images\\switzerland\\10_chateau_de_gruyeres.jpg',
#  'Aletsch Glacier': 'images\\switzerland\\11_aletsch_glacier.jpg',
#  'Lauterbrunnen': 'images\\switzerland\\12_lauterbrunnen.jpg',
#  'Rheinfall': 'images\\switzerland\\13_rheinfall.jpg',
#  'Zermatt': 'images\\switzerland\\14_zermatt.jpg',
#  'Lion Monument': 'images\\switzerland\\15_lion_monument.jpg',
#  'Schilthorn': 'images\\switzerland\\16_schilthorn.jpg',
#  'Lenzburg Castle': 'images\\switzerland\\17_lenzburg_castle.jpg',
#  'Grossmünster': 'images\\switzerland\\18_grossmuenster.jpg',
#  "Jet d'Eau Lake Geneva": 'images\\switzerland\\19_jet_d_eau_lake_geneva.jpg',
#  'Zytglogge': 'images\\switzerland\\20_zytglogge.jpg'}

# %%
def ask_question_about_region(region_list:list, region_paths:dict, question:str):
    answers = []
    for item in region_list:
        answer, confidence = vilt_vqa(region_paths[item], question, False)
        answers.append((item, answer, confidence))
    return answers

# %%
def ask_question_about_all(question:str):
    print(f"Predicting answers for the question '{question}'")
    switzerland_answers = ask_question_about_region(switzerland_list, switzerland_paths, question)
    print(f"Switzerland completed")
    international_answers = ask_question_about_region(international_list, international_paths, question)
    print(f"International completed")
    grisons_answers = ask_question_about_region(grisons_list, grisons_paths, question)
    print(f"Grisons completed\n------------------------------------------------")
    return switzerland_answers, international_answers, grisons_answers

# %%
def build_df(question:str, switzerland_answers:list, international_answers:list, grisons_answers:list, write_csv:bool):
    # Create DataFrames
    df_switzerland = pd.DataFrame(switzerland_answers, columns=["Location", "Answer", "Confidence"])
    df_international = pd.DataFrame(international_answers, columns=["Location", "Answer", "Confidence"])
    df_grisons = pd.DataFrame(grisons_answers, columns=["Location", "Answer", "Confidence"])

    # Add a "Region" column to each DataFrame
    df_switzerland["Region"] = "Switzerland"
    df_international["Region"] = "International"
    df_grisons["Region"] = "Grisons"

    # Add a "Question" column to each DataFrame
    df_switzerland.insert(0, "Question", question)
    df_international.insert(0, "Question", question)
    df_grisons.insert(0, "Question", question)

    # Concatenate the DataFrames
    df_combined = pd.concat([df_switzerland, df_international, df_grisons], ignore_index=True)

    # write csv if desired
    if write_csv == True:
        string = question.lower().replace(" ", "_").replace("?", "")
        string += ".csv"
        path = os.path.join("predictions", string)
        df_combined.to_csv(path, index=False, encoding='utf-8')

    return df_combined

# %%
question = "What is this?"
switzerland_answers, international_answers, grisons_answers = ask_question_about_all(question)
df = build_df(question, switzerland_answers, international_answers, grisons_answers, True)

switzerland_rows = df[df['Region'] == 'Switzerland']
average_confidence_switzerland = switzerland_rows['Confidence'].mean()

international_rows = df[df['Region'] == 'International']
average_confidence_international = international_rows['Confidence'].mean()

grisons_rows = df[df['Region'] == 'Grisons']
average_confidence_grisons = grisons_rows['Confidence'].mean()

average_confidence = df['Confidence'].mean()

print(f"Average Confidence Switzerland:\t\t{average_confidence_switzerland:.4f}")
print(f"Average Confidence International:\t{average_confidence_international:.4f}")
print(f"Average Confidence Grisons:\t\t{average_confidence_grisons:.4f}")
print(f"Average Confidence Total:\t\t{average_confidence:.4f}")
print("------------------------------------------------")
df
# Out:
# Predicting answers for the question 'What is this?'
# Switzerland completed
# International completed
# Grisons completed
# ------------------------------------------------
# Average Confidence Switzerland:		0.6026
# Average Confidence International:	0.6071
# Average Confidence Grisons:		0.5825
# Average Confidence Total:		0.5974
# ------------------------------------------------
#          Question               Location       Answer  Confidence  \
# 0   What is this?             Matterhorn     mountain      0.9562
# 1   What is this?             Bundeshaus     building      0.6159
# 2   What is this?     Chateau de Chillon       castle      0.9067
# 3   What is this?           Creux du Van       bridge      0.9412
# 4   What is this?          Bern Old City       bridge      0.1470
# 5   What is this?           Jungfraujoch     mountain      0.8022
# 6   What is this?           Kapellbrücke       bridge      0.6213
# 7   What is this?                 Ascona        beach      0.5799
# 8   What is this?            Grindelwald   ski resort      0.5198
# 9   What is this?    Chateau de Gruyeres       castle      0.8702
# 10  What is this?        Aletsch Glacier    mountains      0.2721
# 11  What is this?          Lauterbrunnen    mountains      0.4308
# 12  What is this?              Rheinfall       bridge      0.5571
# 13  What is this?                Zermatt   ski resort      0.2888
# 14  What is this?          Lion Monument         oven      0.3160
# 15  What is this?             Schilthorn     mountain      0.2442
# 16  What is this?        Lenzburg Castle        house      0.9016
# 17  What is this?           Grossmünster  clock tower      0.5260
# 18  What is this?  Jet d'Eau Lake Geneva        water      0.7396
# 19  What is this?              Zytglogge  clock tower      0.8153
# 20  What is this?           Eiffel Tower        tower      0.7900
# 21  What is this?                  Uluru     mountain      0.4295
# 22  What is this?                 Louvre     building      0.2244
# 23  What is this?           Lady Liberty       statue      0.9446
# 24  What is this?              Colosseum     building      0.5986
# 25  What is this?          Niagara Falls        water      0.4826
# 26  What is this?           Disney World  clock tower      0.5359
# 27  What is this?         Forbidden City        china      0.4954
# 28  What is this?     Golden Gate Bridge       bridge      0.8394
# 29  What is this?           Times Square         city      0.2865
# 30  What is this?             Notre Dame       church      0.7957
# 31  What is this?        Sagrada Familia     building      0.6852
# 32  What is this?  Neuschwanstein Castle       castle      0.9830
# 33  What is this?     Sydney Opera House         boat      0.4596
# 34  What is this?             Great Wall     mountain      0.4346
# 35  What is this?     Florence Cathedral       church      0.4278
# 36  What is this?         Mount Rushmore       statue      0.4149
# 37  What is this?        Brooklyn Bridge       bridge      0.9262
# 38  What is this?           Grand Canyon    mountains      0.7909
# 39  What is this?        Las Vegas Strip         city      0.5982
# 40  What is this?                  Arosa         lake      0.8775
# 41  What is this?                 Bergün       street      0.3828
# 42  What is this?       Lai da Palpuogna         lake      0.5751
# 43  What is this?                samedan     mountain      0.3826
# 44  What is this?                S-chanf       bridge      0.9142
# 45  What is this?     Landwasser Viaduct       bridge      0.5195
# 46  What is this?  Brusio Spiral Viaduct        train      0.9793
# 47  What is this?                   Chur         city      0.2884
# 48  What is this?        Lake Silvaplana        kites      0.4249
# 49  What is this?             St. Moritz         city      0.7392
# 50  What is this?             Lake Cauma         snow      0.1988
# 51  What is this?             White Turf       horses      0.6838
# 52  What is this?                 Guarda         kite      0.2212
# 53  What is this?        Davos Schatzalp        train      0.9937
# 54  What is this?              Ruinaulta    mountains      0.6980
# 55  What is this?              Maienfeld        trees      0.0960
# 56  What is this?         Muottas Muragl        train      0.9513
# 57  What is this?            Oberengadin    mountains      0.4278
# 58  What is this?               San Gian  clock tower      0.6281
# 59  What is this?     Corviglia Piz Nair     ski lift      0.6674
#
#            Region
# 0     Switzerland
# 1     Switzerland
# 2     Switzerland
# 3     Switzerland
# 4     Switzerland
# 5     Switzerland
# 6     Switzerland
# 7     Switzerland
# 8     Switzerland
# 9     Switzerland
# 10    Switzerland
# 11    Switzerland
# 12    Switzerland
# 13    Switzerland
# 14    Switzerland
# 15    Switzerland
# 16    Switzerland
# 17    Switzerland
# 18    Switzerland
# 19    Switzerland
# 20  International
# 21  International
# 22  International
# 23  International
# 24  International
# 25  International
# 26  International
# 27  International
# 28  International
# 29  International
# 30  International
# 31  International
# 32  International
# 33  International
# 34  International
# 35  International
# 36  International
# 37  International
# 38  International
# 39  International
# 40        Grisons
# 41        Grisons
# 42        Grisons
# 43        Grisons
# 44        Grisons
# 45        Grisons
# 46        Grisons
# 47        Grisons
# 48        Grisons
# 49        Grisons
# 50        Grisons
# 51        Grisons
# 52        Grisons
# 53        Grisons
# 54        Grisons
# 55        Grisons
# 56        Grisons
# 57        Grisons
# 58        Grisons
# 59        Grisons

# %%
question_list = ["What is this?", "What is this called?", "What is the name of this", "What country is this?", "Where is this?", "Which region is this in?", "What can people do here?", "What is this famous for?", "What is special here?", "What is the best time to visit here?", "Is this expensive?", "Is this in nature?", "Is this in a city?", "What sport can I do here?", "Is this a tourist attraction?", "What are activities here?"]
df_list = []

# %%
for i in range(len(question_list)):
    switzerland_answers, international_answers, grisons_answers = ask_question_about_all(question_list[i])
    df= build_df(question_list[i], switzerland_answers, international_answers, grisons_answers, write_csv=True)
    df_list.append(df)

    switzerland_rows = df[df['Region'] == 'Switzerland']
    average_confidence_switzerland = switzerland_rows['Confidence'].mean()

    international_rows = df[df['Region'] == 'International']
    average_confidence_international = international_rows['Confidence'].mean()

    grisons_rows = df[df['Region'] == 'Grisons']
    average_confidence_grisons = grisons_rows['Confidence'].mean()

    average_confidence = df['Confidence'].mean()
    
    print(f"Average Confidence Switzerland:\t\t{average_confidence_switzerland:.4f}")
    print(f"Average Confidence International:\t{average_confidence_international:.4f}")
    print(f"Average Confidence Grisons:\t\t{average_confidence_grisons:.4f}")
    print(f"Average Confidence Total:\t\t{average_confidence:.4f}")
    print("------------------------------------------------")
# Out:
# Predicting answers for the question 'What is this?'
# Switzerland completed
# International completed
# Grisons completed
# ------------------------------------------------
# Average Confidence Switzerland:		0.6026
# Average Confidence International:	0.6071
# Average Confidence Grisons:		0.5825
# Average Confidence Total:		0.5974
# ------------------------------------------------
# Predicting answers for the question 'What is this called?'
# Switzerland completed
# International completed
# Grisons completed
# ------------------------------------------------
# Average Confidence Switzerland:		0.5977
# Average Confidence International:	0.5884
# Average Confidence Grisons:		0.5229
# Average Confidence Total:		0.5697
# ------------------------------------------------
# Predicting answers for the question 'What is the name of this'
# Switzerland completed
# International completed
# Grisons completed
# ------------------------------------------------
# Average Confidence Switzerland:		0.4416
# Average Confidence International:	0.3518
# Average Confidence Grisons:		0.3467
# Average Confidence Total:		0.3800
# ------------------------------------------------
# Predicting answers for the question 'What country is this?'
# Switzerland completed
# International completed
# Grisons completed
# ------------------------------------------------
# Average Confidence Switzerland:		0.3775
# Average Confidence International:	0.4358
# Average Confidence Grisons:		0.3742
# Average Confidence Total:		0.3958
# ------------------------------------------------
# Predicting answers for the question 'Where is this?'
# Switzerland completed
# International completed
# Grisons completed
# ------------------------------------------------
# Average Confidence Switzerland:		0.4605
# Average Confidence International:	0.4433
# Average Confidence Grisons:		0.5476
# Average Confidence Total:		0.4838
# ------------------------------------------------
# Predicting answers for the question 'Which region is this in?'
# Switzerland completed
# International completed
# Grisons completed
# ------------------------------------------------
# Average Confidence Switzerland:		0.4195
# Average Confidence International:	0.3326
# Average Confidence Grisons:		0.4339
# Average Confidence Total:		0.3953
# ------------------------------------------------
# Predicting answers for the question 'What can people do here?'
# Switzerland completed
# International completed
# Grisons completed
# ------------------------------------------------
# Average Confidence Switzerland:		0.4077
# Average Confidence International:	0.1876
# Average Confidence Grisons:		0.4026
# Average Confidence Total:		0.3326
# ------------------------------------------------
# Predicting answers for the question 'What is this famous for?'
# Switzerland completed
# International completed
# Grisons completed
# ------------------------------------------------
# Average Confidence Switzerland:		0.3328
# Average Confidence International:	0.3553
# Average Confidence Grisons:		0.4149
# Average Confidence Total:		0.3677
# ------------------------------------------------
# Predicting answers for the question 'What is special here?'
# Switzerland completed
# International completed
# Grisons completed
# ------------------------------------------------
# Average Confidence Switzerland:		0.3673
# Average Confidence International:	0.3595
# Average Confidence Grisons:		0.4181
# Average Confidence Total:		0.3816
# ------------------------------------------------
# Predicting answers for the question 'What is the best time to visit here?'
# Switzerland completed
# International completed
# Grisons completed
# ------------------------------------------------
# Average Confidence Switzerland:		0.2119
# Average Confidence International:	0.2406
# Average Confidence Grisons:		0.2796
# Average Confidence Total:		0.2440
# ------------------------------------------------
# Predicting answers for the question 'Is this expensive?'
# Switzerland completed
# International completed
# Grisons completed
# ------------------------------------------------
# Average Confidence Switzerland:		0.8807
# Average Confidence International:	0.9174
# Average Confidence Grisons:		0.8936
# Average Confidence Total:		0.8972
# ------------------------------------------------
# Predicting answers for the question 'Is this in nature?'
# Switzerland completed
# International completed
# Grisons completed
# ------------------------------------------------
# Average Confidence Switzerland:		0.9411
# Average Confidence International:	0.9664
# Average Confidence Grisons:		0.9438
# Average Confidence Total:		0.9505
# ------------------------------------------------
# Predicting answers for the question 'Is this in a city?'
# Switzerland completed
# International completed
# Grisons completed
# ------------------------------------------------
# Average Confidence Switzerland:		0.9701
# Average Confidence International:	0.9658
# Average Confidence Grisons:		0.9622
# Average Confidence Total:		0.9660
# ------------------------------------------------
# Predicting answers for the question 'What sport can I do here?'
# Switzerland completed
# International completed
# Grisons completed
# ------------------------------------------------
# Average Confidence Switzerland:		0.4128
# Average Confidence International:	0.3105
# Average Confidence Grisons:		0.3955
# Average Confidence Total:		0.3729
# ------------------------------------------------
# Predicting answers for the question 'Is this a tourist attraction?'
# Switzerland completed
# International completed
# Grisons completed
# ------------------------------------------------
# Average Confidence Switzerland:		0.9986
# Average Confidence International:	0.9769
# Average Confidence Grisons:		0.9739
# Average Confidence Total:		0.9831
# ------------------------------------------------
# Predicting answers for the question 'What are activities here?'
# Switzerland completed
# International completed
# Grisons completed
# ------------------------------------------------
# Average Confidence Switzerland:		0.3283
# Average Confidence International:	0.2340
# Average Confidence Grisons:		0.3617
# Average Confidence Total:		0.3080
# ------------------------------------------------

# %%
# looking at results
df_list[0]

# %%
switzerland_answers, international_answers, grisons_answers = ask_question_about_all("What language do people speak here?")
df= build_df("What language do people speak here?", switzerland_answers, international_answers, grisons_answers, write_csv=True)
df
# Out:
# Predicting answers for the question 'What language do people speak here?'
# Switzerland completed
# International completed
# Grisons completed
# ------------------------------------------------
#                                Question               Location   Answer  \
# 0   What language do people speak here?             Matterhorn  english
# 1   What language do people speak here?             Bundeshaus  english
# 2   What language do people speak here?     Chateau de Chillon  spanish
# 3   What language do people speak here?           Creux du Van  spanish
# 4   What language do people speak here?          Bern Old City  chinese
# 5   What language do people speak here?           Jungfraujoch  english
# 6   What language do people speak here?           Kapellbrücke   french
# 7   What language do people speak here?                 Ascona  spanish
# 8   What language do people speak here?            Grindelwald   french
# 9   What language do people speak here?    Chateau de Gruyeres  spanish
# 10  What language do people speak here?        Aletsch Glacier  english
# 11  What language do people speak here?          Lauterbrunnen   french
# 12  What language do people speak here?              Rheinfall  spanish
# 13  What language do people speak here?                Zermatt   french
# 14  What language do people speak here?          Lion Monument  spanish
# 15  What language do people speak here?             Schilthorn   french
# 16  What language do people speak here?        Lenzburg Castle  english
# 17  What language do people speak here?           Grossmünster  english
# 18  What language do people speak here?  Jet d'Eau Lake Geneva  english
# 19  What language do people speak here?              Zytglogge  english
# 20  What language do people speak here?           Eiffel Tower  english
# 21  What language do people speak here?                  Uluru  spanish
# 22  What language do people speak here?                 Louvre   french
# 23  What language do people speak here?           Lady Liberty  english
# 24  What language do people speak here?              Colosseum  english
# 25  What language do people speak here?          Niagara Falls  spanish
# 26  What language do people speak here?           Disney World  english
# 27  What language do people speak here?         Forbidden City  chinese
# 28  What language do people speak here?     Golden Gate Bridge  english
# 29  What language do people speak here?           Times Square  chinese
# 30  What language do people speak here?             Notre Dame  english
# 31  What language do people speak here?        Sagrada Familia  english
# 32  What language do people speak here?  Neuschwanstein Castle  english
# 33  What language do people speak here?     Sydney Opera House  english
# 34  What language do people speak here?             Great Wall  spanish
# 35  What language do people speak here?     Florence Cathedral  spanish
# 36  What language do people speak here?         Mount Rushmore  spanish
# 37  What language do people speak here?        Brooklyn Bridge  english
# 38  What language do people speak here?           Grand Canyon  english
# 39  What language do people speak here?        Las Vegas Strip  chinese
# 40  What language do people speak here?                  Arosa   french
# 41  What language do people speak here?                 Bergün  spanish
# 42  What language do people speak here?       Lai da Palpuogna   french
# 43  What language do people speak here?                samedan  english
# 44  What language do people speak here?                S-chanf   french
# 45  What language do people speak here?     Landwasser Viaduct   german
# 46  What language do people speak here?  Brusio Spiral Viaduct   german
# 47  What language do people speak here?                   Chur  spanish
# 48  What language do people speak here?        Lake Silvaplana  english
# 49  What language do people speak here?             St. Moritz   french
# 50  What language do people speak here?             Lake Cauma  english
# 51  What language do people speak here?             White Turf  english
# 52  What language do people speak here?                 Guarda  spanish
# 53  What language do people speak here?        Davos Schatzalp  english
# 54  What language do people speak here?              Ruinaulta  spanish
# 55  What language do people speak here?              Maienfeld  english
# 56  What language do people speak here?         Muottas Muragl  english
# 57  What language do people speak here?            Oberengadin   french
# 58  What language do people speak here?               San Gian  english
# 59  What language do people speak here?     Corviglia Piz Nair  english
#
#     Confidence         Region
# 0       0.3019    Switzerland
# 1       0.7522    Switzerland
# 2       0.3803    Switzerland
# 3       0.2742    Switzerland
# 4       0.3457    Switzerland
# 5       0.2761    Switzerland
# 6       0.2807    Switzerland
# 7       0.4287    Switzerland
# 8       0.3174    Switzerland
# 9       0.2644    Switzerland
# 10      0.2715    Switzerland
# 11      0.2749    Switzerland
# 12      0.2858    Switzerland
# 13      0.2249    Switzerland
# 14      0.3138    Switzerland
# 15      0.3462    Switzerland
# 16      0.3600    Switzerland
# 17      0.6300    Switzerland
# 18      0.7688    Switzerland
# 19      0.3115    Switzerland
# 20      0.8533  International
# 21      0.3191  International
# 22      0.2938  International
# 23      0.2600  International
# 24      0.3787  International
# 25      0.3436  International
# 26      0.5803  International
# 27      0.7675  International
# 28      0.6227  International
# 29      0.4025  International
# 30      0.7369  International
# 31      0.7418  International
# 32      0.3537  International
# 33      0.2312  International
# 34      0.3575  International
# 35      0.2039  International
# 36      0.4659  International
# 37      0.4604  International
# 38      0.3500  International
# 39      0.2084  International
# 40      0.4067        Grisons
# 41      0.2920        Grisons
# 42      0.3313        Grisons
# 43      0.4398        Grisons
# 44      0.2575        Grisons
# 45      0.2920        Grisons
# 46      0.2830        Grisons
# 47      0.2491        Grisons
# 48      0.5665        Grisons
# 49      0.1858        Grisons
# 50      0.3094        Grisons
# 51      0.9072        Grisons
# 52      0.3800        Grisons
# 53      0.2743        Grisons
# 54      0.2596        Grisons
# 55      0.4208        Grisons
# 56      0.1915        Grisons
# 57      0.2758        Grisons
# 58      0.5073        Grisons
# 59      0.3540        Grisons

# %% [markdown]
# ____________________
# ## Testing 1: Advanced question structure
# **Theory**: To achieve better results, two questions can be chained.
#
# In some situations while testing, answers were better when the question is more specific.
#
# Generic Question: Picture - Eiffel Tower; Question - What is the name of this?; Answer - tower
#
# Specific Question: Picture - Eiffel Tower; Question - What is the name of this tower?; Answer: eiffel tower
#
# **Goal**: Extract information with a first question "What is this?" Answer: tower
#
# Then, a second question will be formulated, integrating the answer of the first question. "What is the name of this tower?" Answer: eiffel tower

# %%
# complex question structure
question_1 = "What is this?"
switzerland_answers_1, international_answers_1, grisons_answers_1 = ask_question_about_all(question_1)

switzerland_answers_2 = []
for i in range(len(switzerland_answers_1)):
    question_2 = f"What is the name of this {switzerland_answers_1[i][1]}?"
    print(f"Question 2: {question_2}")

    if i < 9:
        number_string = "0" + str(i+1)
    else:
        number_string = str(i+1)
    path = build_path("switzerland", number_string, switzerland_list[i])
    print(path)
    answer_2, confidence_2 = vilt_vqa(switzerland_paths[switzerland_list[i]], question_2, False)
    switzerland_answers_2.append((switzerland_list[i], switzerland_answers_1[i][1], answer_2, confidence_2))
print("Switzerland 2 completed")

international_answers_2 = []
for i in range(len(international_answers_1)):
    question_2 = f"What is the name of this {international_answers_1[i][1]}?"
    print(f"Question 2: {question_2}")

    if i < 9:
        number_string = "0" + str(i+1)
    else:
        number_string = str(i+1)
    path = build_path("international", number_string, international_list[i])
    print(path)
    answer_2, confidence_2 = vilt_vqa(international_paths[international_list[i]], question_2, False)
    international_answers_2.append((international_list[i], international_answers_1[i][1], answer_2, confidence_2))
print("International 2 completed")

grisons_answers_2 = []
for i in range(len(grisons_answers_1)):
    question_2 = f"What is the name of this {grisons_answers_1[i][1]}?"
    print(f"Question 2: {question_2}")

    if i < 9:
        number_string = "0" + str(i+1)
    else:
        number_string = str(i+1)
    path = build_path("grisons", number_string, grisons_list[i])
    print(path)
    answer_2, confidence_2 = vilt_vqa(grisons_paths[grisons_list[i]], question_2, False)
    grisons_answers_2.append((grisons_list[i], grisons_answers_1[i][1], answer_2, confidence_2))
print("Grisons 2 completed")
# Out:
# Predicting answers for the question 'What is this?'
# Switzerland completed
# International completed
# Grisons completed
# ------------------------------------------------
# Question 2: What is the name of this mountain?
# images\switzerland\01_matterhorn.jpg
# Question 2: What is the name of this building?
# images\switzerland\02_bundeshaus.jpg
# Question 2: What is the name of this castle?
# images\switzerland\03_chateau_de_chillon.jpg
# Question 2: What is the name of this bridge?
# images\switzerland\04_creux_du_van.jpg
# Question 2: What is the name of this bridge?
# images\switzerland\05_bern_old_city.jpg
# Question 2: What is the name of this mountain?
# images\switzerland\06_jungfraujoch.jpg
# Question 2: What is the name of this bridge?
# images\switzerland\07_kapellbruecke.jpg
# Question 2: What is the name of this beach?
# images\switzerland\08_ascona.jpg
# Question 2: What is the name of this ski resort?
# images\switzerland\09_grindelwald.jpg
# Question 2: What is the name of this castle?
# images\switzerland\10_chateau_de_gruyeres.jpg
# Question 2: What is the name of this mountains?
# images\switzerland\11_aletsch_glacier.jpg
# Question 2: What is the name of this mountains?
# images\switzerland\12_lauterbrunnen.jpg
# Question 2: What is the name of this bridge?
# images\switzerland\13_rheinfall.jpg
# Question 2: What is the name of this ski resort?
# images\switzerland\14_zermatt.jpg
# Question 2: What is the name of this oven?
# images\switzerland\15_lion_monument.jpg
# Question 2: What is the name of this mountain?
# images\switzerland\16_schilthorn.jpg
# Question 2: What is the name of this house?
# images\switzerland\17_lenzburg_castle.jpg
# Question 2: What is the name of this clock tower?
# images\switzerland\18_grossmuenster.jpg
# Question 2: What is the name of this water?
# images\switzerland\19_jet_d_eau_lake_geneva.jpg
# Question 2: What is the name of this clock tower?
# images\switzerland\20_zytglogge.jpg
# Switzerland 2 completed
# Question 2: What is the name of this tower?
# images\international\01_eiffel_tower.jpg
# Question 2: What is the name of this mountain?
# images\international\02_uluru.jpg
# Question 2: What is the name of this building?
# images\international\03_louvre.jpg
# Question 2: What is the name of this statue?
# images\international\04_lady_liberty.jpg
# Question 2: What is the name of this building?
# images\international\05_colosseum.jpg
# Question 2: What is the name of this water?
# images\international\06_niagara_falls.jpg
# Question 2: What is the name of this clock tower?
# images\international\07_disney_world.jpg
# Question 2: What is the name of this china?
# images\international\08_forbidden_city.jpg
# Question 2: What is the name of this bridge?
# images\international\09_golden_gate_bridge.jpg
# Question 2: What is the name of this city?
# images\international\10_times_square.jpg
# Question 2: What is the name of this church?
# images\international\11_notre_dame.jpg
# Question 2: What is the name of this building?
# images\international\12_sagrada_familia.jpg
# Question 2: What is the name of this castle?
# images\international\13_neuschwanstein_castle.jpg
# Question 2: What is the name of this boat?
# images\international\14_sydney_opera_house.jpg
# Question 2: What is the name of this mountain?
# images\international\15_great_wall.jpg
# Question 2: What is the name of this church?
# images\international\16_florence_cathedral.jpg
# Question 2: What is the name of this statue?
# images\international\17_mount_rushmore.jpg
# Question 2: What is the name of this bridge?
# images\international\18_brooklyn_bridge.jpg
# Question 2: What is the name of this mountains?
# images\international\19_grand_canyon.jpg
# Question 2: What is the name of this city?
# images\international\20_las_vegas_strip.jpg
# International 2 completed
# Question 2: What is the name of this lake?
# images\grisons\01_arosa.jpg
# Question 2: What is the name of this street?
# images\grisons\02_berguen.jpg
# Question 2: What is the name of this lake?
# images\grisons\03_lai_da_palpuogna.jpg
# Question 2: What is the name of this mountain?
# images\grisons\04_samedan.jpg
# Question 2: What is the name of this bridge?
# images\grisons\05_s_chanf.jpg
# Question 2: What is the name of this bridge?
# images\grisons\06_landwasser_viaduct.jpg
# Question 2: What is the name of this train?
# images\grisons\07_brusio_spiral_viaduct.jpg
# Question 2: What is the name of this city?
# images\grisons\08_chur.jpg
# Question 2: What is the name of this kites?
# images\grisons\09_lake_silvaplana.jpg
# Question 2: What is the name of this city?
# images\grisons\10_st_moritz.jpg
# Question 2: What is the name of this snow?
# images\grisons\11_lake_cauma.jpg
# Question 2: What is the name of this horses?
# images\grisons\12_white_turf.jpg
# Question 2: What is the name of this kite?
# images\grisons\13_guarda.jpg
# Question 2: What is the name of this train?
# images\grisons\14_davos_schatzalp.jpg
# Question 2: What is the name of this mountains?
# images\grisons\15_ruinaulta.jpg
# Question 2: What is the name of this trees?
# images\grisons\16_maienfeld.jpg
# Question 2: What is the name of this train?
# images\grisons\17_muottas_muragl.jpg
# Question 2: What is the name of this mountains?
# images\grisons\18_oberengadin.jpg
# Question 2: What is the name of this clock tower?
# images\grisons\19_san_gian.jpg
# Question 2: What is the name of this ski lift?
# images\grisons\20_corviglia_piz_nair.jpg
# Grisons 2 completed

# %%
switzerland_answers_2
# Out:
# [('Matterhorn', 'mountain', 'unknown', 0.1681),
#  ('Bundeshaus', 'building', 'white house', 0.324),
#  ('Chateau de Chillon', 'castle', 'castle', 0.2481),
#  ('Creux du Van', 'bridge', 'bridge', 0.1234),
#  ('Bern Old City', 'bridge', 'golden gate', 0.1429),
#  ('Jungfraujoch', 'mountain', 'alps', 0.2876),
#  ('Kapellbrücke', 'bridge', "don't know", 0.1718),
#  ('Ascona', 'beach', 'unknown', 0.2161),
#  ('Grindelwald', 'ski resort', 'unknown', 0.2085),
#  ('Chateau de Gruyeres', 'castle', 'castle', 0.3097),
#  ('Aletsch Glacier', 'mountains', 'alps', 0.6846),
#  ('Lauterbrunnen', 'mountains', 'alps', 0.5327),
#  ('Rheinfall', 'bridge', 'train', 0.3492),
#  ('Zermatt', 'ski resort', 'unknown', 0.1693),
#  ('Lion Monument', 'oven', 'pizza', 0.1285),
#  ('Schilthorn', 'mountain', 'alps', 0.4925),
#  ('Lenzburg Castle', 'house', 'house', 0.143),
#  ('Grossmünster', 'clock tower', 'big ben', 0.9954),
#  ("Jet d'Eau Lake Geneva", 'water', 'ocean', 0.163),
#  ('Zytglogge', 'clock tower', 'big ben', 0.5711)]

# %%
international_answers_2
# Out:
# [('Eiffel Tower', 'tower', 'eiffel tower', 0.2466),
#  ('Uluru', 'mountain', 'rocky', 0.1166),
#  ('Louvre', 'building', 'big ben', 0.2527),
#  ('Lady Liberty', 'statue', 'washington', 0.1546),
#  ('Colosseum', 'building', 'church', 0.0849),
#  ('Niagara Falls', 'water', 'ocean', 0.1413),
#  ('Disney World', 'clock tower', 'big ben', 0.9809),
#  ('Forbidden City', 'china', 'china', 0.3814),
#  ('Golden Gate Bridge', 'bridge', 'golden gate', 0.8134),
#  ('Times Square', 'city', 'new york', 0.8351),
#  ('Notre Dame', 'church', 'church', 0.4182),
#  ('Sagrada Familia', 'building', 'church', 0.9403),
#  ('Neuschwanstein Castle', 'castle', 'castle', 0.7632),
#  ('Sydney Opera House', 'boat', 'boat', 0.0556),
#  ('Great Wall', 'mountain', 'unknown', 0.2253),
#  ('Florence Cathedral', 'church', 'church', 0.5883),
#  ('Mount Rushmore', 'statue', 'unknown', 0.0812),
#  ('Brooklyn Bridge', 'bridge', 'golden gate', 0.6032),
#  ('Grand Canyon', 'mountains', 'unknown', 0.1753),
#  ('Las Vegas Strip', 'city', 'new york', 0.7776)]

# %%
grisons_answers_2
# Out:
# [('Arosa', 'lake', 'lake', 0.2391),
#  ('Bergün', 'street', 'main', 0.6778),
#  ('Lai da Palpuogna', 'lake', 'unknown', 0.2017),
#  ('samedan', 'mountain', 'alps', 0.201),
#  ('S-chanf', 'bridge', "don't know", 0.1241),
#  ('Landwasser Viaduct', 'bridge', 'train', 0.2434),
#  ('Brusio Spiral Viaduct', 'train', 'thomas', 0.3048),
#  ('Chur', 'city', 'london', 0.2499),
#  ('Lake Silvaplana', 'kites', 'kites', 0.2004),
#  ('St. Moritz', 'city', 'london', 0.2665),
#  ('Lake Cauma', 'snow', 'snow', 0.3717),
#  ('White Turf', 'horses', 'horses', 0.1757),
#  ('Guarda', 'kite', 'bird', 0.1412),
#  ('Davos Schatzalp', 'train', 'unknown', 0.1434),
#  ('Ruinaulta', 'mountains', 'alps', 0.2913),
#  ('Maienfeld', 'trees', 'pine', 0.3008),
#  ('Muottas Muragl', 'train', 'red', 0.1747),
#  ('Oberengadin', 'mountains', 'alps', 0.4051),
#  ('San Gian', 'clock tower', 'big ben', 0.6896),
#  ('Corviglia Piz Nair', 'ski lift', 'unknown', 0.2302)]

# %% [markdown]
# ___________
# ## Testing 2: Plausibility tests with basic images

# %%
test_paths = [r"images\test\01_chair.jpg", r"images\test\02_lamp.jpg", r"images\test\03_apple.jpg"]
test_questions = ["What country is this?", "What language do people speak here?", "What can people do here?", "Is this a tourist attraction?", "Is this in Switzerland?", "What is the name of this?", "Can I eat this?", "What is the material of this?"]

for i in range(len(test_questions)):
    for j in range(len(test_paths)):
        test_answer = vilt_vqa(test_paths[j], test_questions[i], False)
        print(f"Image: {os.path.basename(test_paths[j])}, Question: {test_questions[i]}, Answer: {test_answer}")
    print("---------------------------------------------------")
# Out:
# Image: 01_chair.jpg, Question: What country is this?, Answer: ('usa', 0.3684)
# Image: 02_lamp.jpg, Question: What country is this?, Answer: ('japan', 0.4154)
# Image: 03_apple.jpg, Question: What country is this?, Answer: ('usa', 0.3415)
# ---------------------------------------------------
# Image: 01_chair.jpg, Question: What language do people speak here?, Answer: ('english', 0.8774)
# Image: 02_lamp.jpg, Question: What language do people speak here?, Answer: ('chinese', 0.3513)
# Image: 03_apple.jpg, Question: What language do people speak here?, Answer: ('english', 0.6884)
# ---------------------------------------------------
# Image: 01_chair.jpg, Question: What can people do here?, Answer: ('eat', 0.2086)
# Image: 02_lamp.jpg, Question: What can people do here?, Answer: ('pee', 0.0966)
# Image: 03_apple.jpg, Question: What can people do here?, Answer: ('eat', 0.7822)
# ---------------------------------------------------
# Image: 01_chair.jpg, Question: Is this a tourist attraction?, Answer: ('no', 0.9999)
# Image: 02_lamp.jpg, Question: Is this a tourist attraction?, Answer: ('no', 0.9854)
# Image: 03_apple.jpg, Question: Is this a tourist attraction?, Answer: ('no', 0.9999)
# ---------------------------------------------------
# Image: 01_chair.jpg, Question: Is this in Switzerland?, Answer: ('no', 0.9532)
# Image: 02_lamp.jpg, Question: Is this in Switzerland?, Answer: ('yes', 0.7646)
# Image: 03_apple.jpg, Question: Is this in Switzerland?, Answer: ('no', 0.9943)
# ---------------------------------------------------
# Image: 01_chair.jpg, Question: What is the name of this?, Answer: ('chair', 0.896)
# Image: 02_lamp.jpg, Question: What is the name of this?, Answer: ('light', 0.1809)
# Image: 03_apple.jpg, Question: What is the name of this?, Answer: ('apple', 0.9866)
# ---------------------------------------------------
# Image: 01_chair.jpg, Question: Can I eat this?, Answer: ('no', 0.9988)
# Image: 02_lamp.jpg, Question: Can I eat this?, Answer: ('no', 0.9993)
# Image: 03_apple.jpg, Question: Can I eat this?, Answer: ('yes', 0.9984)
# ---------------------------------------------------
# Image: 01_chair.jpg, Question: What is the material of this?, Answer: ('metal', 0.3103)
# Image: 02_lamp.jpg, Question: What is the material of this?, Answer: ('plastic', 0.3832)
# Image: 03_apple.jpg, Question: What is the material of this?, Answer: ('metal', 0.2997)
# ---------------------------------------------------

# %% [markdown]
# ___________________________________
# ## Testing 3: trying out specific questions / pictures

# %%
# prepare image + question
image_path = r'images\international\01_eiffel_tower.jpg'
image = Image.open(image_path)
text = "What is the name of this?"

processor = ViltProcessor.from_pretrained("dandelin/vilt-b32-finetuned-vqa")
model = ViltForQuestionAnswering.from_pretrained("dandelin/vilt-b32-finetuned-vqa")

# prepare inputs
encoding = processor(image, text, return_tensors="pt")

# forward pass
outputs = model(**encoding)
logits = outputs.logits
idx = logits.argmax(-1).item()
print("Predicted answer:", model.config.id2label[idx])
# Out:
# Predicted answer: tower

# %%
# prepare image + question
image_path = r'images\international\01_eiffel_tower.jpg'
image = Image.open(image_path)
text = "What is the name of this tower?"

processor = ViltProcessor.from_pretrained("dandelin/vilt-b32-finetuned-vqa")
model = ViltForQuestionAnswering.from_pretrained("dandelin/vilt-b32-finetuned-vqa")

# prepare inputs
encoding = processor(image, text, return_tensors="pt")

# forward pass
outputs = model(**encoding)
logits = outputs.logits
idx = logits.argmax(-1).item()
print("Predicted answer:", model.config.id2label[idx])
# Out:
# Predicted answer: eiffel tower

# %%
# prepare image + question
image_path = r'images\international\eiffelturm.jpg'
image = Image.open(image_path)
text = "Where is this?"

processor = ViltProcessor.from_pretrained("dandelin/vilt-b32-finetuned-vqa")
model = ViltForQuestionAnswering.from_pretrained("dandelin/vilt-b32-finetuned-vqa")

# prepare inputs
encoding = processor(image, text, return_tensors="pt")

# forward pass
outputs = model(**encoding)
logits = outputs.logits
idx = logits.argmax(-1).item()
print("Predicted answer:", model.config.id2label[idx])
# Out:
# Predicted answer: park

# %%
# prepare image + question
image_path = r'images\international\eiffelturm.jpg'
image = Image.open(image_path)
text = "What city is this?"

processor = ViltProcessor.from_pretrained("dandelin/vilt-b32-finetuned-vqa")
model = ViltForQuestionAnswering.from_pretrained("dandelin/vilt-b32-finetuned-vqa")

# prepare inputs
encoding = processor(image, text, return_tensors="pt")

# forward pass
outputs = model(**encoding)
logits = outputs.logits
idx = logits.argmax(-1).item()
print("Predicted answer:", model.config.id2label[idx])
# Out:
# Predicted answer: paris

# %%
# prepare image + question
image_path = r'images\international\eiffelturm.jpg'
image = Image.open(image_path)
text = "Which country is this?"

processor = ViltProcessor.from_pretrained("dandelin/vilt-b32-finetuned-vqa")
model = ViltForQuestionAnswering.from_pretrained("dandelin/vilt-b32-finetuned-vqa")

# prepare inputs
encoding = processor(image, text, return_tensors="pt")

# forward pass
outputs = model(**encoding)
logits = outputs.logits
idx = logits.argmax(-1).item()
print("Predicted answer:", model.config.id2label[idx])
# Out:
# Predicted answer: usa
